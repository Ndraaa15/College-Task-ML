# %% [markdown]
# ### MBA
# > Market basket analysis adalah teknik penambangan data yang digunakan untuk mengungkap pola pembelian dalam bidang ritel apa pun. Tujuannya adalah memahami perilaku konsumen dengan mengidentifikasi hubungan antara barang-barang yang dibeli.
#
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Assuming you have a list of transactions
transactions = [['bread', 'milk', 'eggs'],
        ['bread', 'diapers'],
        ['milk', 'diapers', 'beer', 'eggs'],
        ['bread', 'milk', 'diapers', 'beer'],
        ['bread', 'milk', 'diapers', 'eggs']]

# Convert the transaction list into a one-hot encoded format
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df, min_support=0.2, use_colnames=True)

# Generate association rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# Print the frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
print(rules)
# Out:
# [[False  True False  True  True]
#  [False  True  True False False]
#  [ True False  True  True  True]
#  [ True  True  True False  True]
#  [False  True  True  True  True]]
# Frequent Itemsets:
#     support                      itemsets
# 0       0.4                        (beer)
# 1       0.8                       (bread)
# 2       0.8                     (diapers)
# 3       0.6                        (eggs)
# 4       0.8                        (milk)
# 5       0.2                 (bread, beer)
# 6       0.4               (beer, diapers)
# 7       0.2                  (eggs, beer)
# 8       0.4                  (milk, beer)
# 9       0.6              (bread, diapers)
# 10      0.4                 (bread, eggs)
# 11      0.6                 (bread, milk)
# 12      0.4               (eggs, diapers)
# 13      0.6               (milk, diapers)
# 14      0.6                  (eggs, milk)
# 15      0.2        (bread, beer, diapers)
# 16      0.2           (bread, milk, beer)
# 17      0.2         (eggs, beer, diapers)
# 18      0.4         (milk, beer, diapers)
# 19      0.2            (eggs, milk, beer)
# 20      0.2        (bread, eggs, diapers)
# 21      0.4        (bread, milk, diapers)
# 22      0.4           (bread, eggs, milk)
# 23      0.4         (eggs, milk, diapers)
# 24      0.2  (bread, milk, beer, diapers)
# 25      0.2   (eggs, milk, beer, diapers)
# 26      0.2  (bread, eggs, milk, diapers)
#
# Association Rules:
#                antecedents      consequents  antecedent support  \
# 0                   (beer)          (bread)                 0.4
# 1                   (beer)        (diapers)                 0.4
# 2                (diapers)           (beer)                 0.8
# 3                   (beer)           (eggs)                 0.4
# 4                   (milk)           (beer)                 0.8
# ..                     ...              ...                 ...
# 75  (bread, eggs, diapers)           (milk)                 0.2
# 76  (bread, milk, diapers)           (eggs)                 0.4
# 77   (eggs, milk, diapers)          (bread)                 0.4
# 78           (bread, eggs)  (milk, diapers)                 0.4
# 79         (eggs, diapers)    (bread, milk)                 0.4
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.8      0.2         0.5  0.625000     -0.12         0.4
# 1                  0.8      0.4         1.0  1.250000      0.08         inf
# 2                  0.4      0.4         0.5  1.250000      0.08         1.2
# 3                  0.6      0.2         0.5  0.833333     -0.04         0.8
# 4                  0.4      0.4         0.5  1.250000      0.08         1.2
# ..                 ...      ...         ...       ...       ...         ...
# 75                 0.8      0.2         1.0  1.250000      0.04         inf
# 76                 0.6      0.2         0.5  0.833333     -0.04         0.8
# 77                 0.8      0.2         0.5  0.625000     -0.12         0.4
# 78                 0.6      0.2         0.5  0.833333     -0.04         0.8
# 79                 0.6      0.2         0.5  0.833333     -0.04         0.8
#
#     zhangs_metric
# 0       -0.500000
# 1        0.333333
# 2        1.000000
# 3       -0.250000
# 4        1.000000
# ..            ...
# 75       0.250000
# 76      -0.250000
# 77      -0.500000
# 78      -0.250000
# 79      -0.250000
#
# [80 rows x 10 columns]
